# %%
# df.head() by default showing first 5 rows 
# df.head(10) we scecify that how many rows i wanna see just like here 10 
# df.tail() by default showing last 5 rows 
# df.tail(10)  we scecify that how many rows i wanna see just like here 10 
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)    .. forcefully displaying all the data
# df.shape
# df.columns
# df.dtypes
# print(df.shape)
